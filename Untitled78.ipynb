# %%
import keras
from keras import layers
import numpy as np
original_dim = 28 * 28
intermediate_dim = 64
latent_dim = 10

inputs = keras.Input(shape=(original_dim,))
h = layers.Dense(intermediate_dim, activation='relu')(inputs)
z_mean = layers.Dense(latent_dim)(h)

z_log_sigma = layers.Dense(latent_dim)(h)
print(z_mean.shape)
from keras import backend as K

def sampling(args):
    z_mean, z_log_sigma = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim),
                              mean=0., stddev=0.1)
    return z_mean + K.exp(z_log_sigma) * epsilon

z = layers.Lambda(sampling)([z_mean, z_log_sigma])

# Create encoder
encoder = keras.Model(inputs, [z_mean, z_log_sigma, z], name='encoder')

# Create decoder
latent_inputs = keras.Input(shape=(latent_dim,), name='z_sampling')
x = layers.Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = layers.Dense(original_dim, activation='sigmoid')(x)
decoder = keras.Model(latent_inputs, outputs, name='decoder')

# instantiate VAE model
outputs = decoder(encoder(inputs)[2])
vae = keras.Model(inputs, outputs, name='vae_mlp')
encoder.summary()

reconstruction_loss = keras.losses.binary_crossentropy(inputs, outputs)
reconstruction_loss *= original_dim
kl_loss = 1 + z_log_sigma - K.square(z_mean) - K.exp(z_log_sigma)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='rmsprop')

from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

vae.fit(x_train, x_train,
        epochs=100,
        batch_size=32)
x_decoded = vae.predict(x_train)
import matplotlib.pyplot as plt
# Display a 2D manifold of the digits
n = 15  # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
# We will sample n points within [-15, 15] standard deviations
grid_x = np.linspace(-15, 15, n)
grid_y = np.linspace(-15, 15, n)
k=0
for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        #x_decoded = decoder.predict(z_sample)
        digit = x_train[k].reshape(digit_size, digit_size)
        k = k +1
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure)
plt.show()
print (k)
import matplotlib.pyplot as plt
# Display a 2D manifold of the digits
n = 15  # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
# We will sample n points within [-15, 15] standard deviations
grid_x = np.linspace(-15, 15, n)
grid_y = np.linspace(-15, 15, n)
k=0
for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        #x_decoded = decoder.predict(z_sample)
        digit = x_decoded[k].reshape(digit_size, digit_size)
        k = k +1
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure)
plt.show()
# Out:
# (None, 10)
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 784)]                0         []
#
#  dense (Dense)               (None, 64)                   50240     ['input_1[0][0]']
#
#  dense_1 (Dense)             (None, 10)                   650       ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 10)                   650       ['dense[0][0]']
#
#  lambda (Lambda)             (None, 10)                   0         ['dense_1[0][0]',
#                                                                      'dense_2[0][0]']
#
# ==================================================================================================
# Total params: 51540 (201.33 KB)
# Trainable params: 51540 (201.33 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 141.7676
# Epoch 2/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 113.6865
# Epoch 3/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 108.4456
# Epoch 4/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 105.8898
# Epoch 5/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 104.3506
# Epoch 6/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 103.2795
# Epoch 7/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 102.5271
# Epoch 8/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 101.8994
# Epoch 9/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 101.3780
# Epoch 10/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 100.9680
# Epoch 11/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 100.5808
# Epoch 12/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 100.2394
# Epoch 13/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 100.0051
# Epoch 14/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 99.7777
# Epoch 15/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 99.5563
# Epoch 16/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 99.3969
# Epoch 17/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 99.2328
# Epoch 18/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 99.1047
# Epoch 19/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 98.9523
# Epoch 20/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 98.8549
# Epoch 21/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 98.7217
# Epoch 22/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 98.6397
# Epoch 23/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 98.5327
# Epoch 24/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 98.4496
# Epoch 25/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 98.3725
# Epoch 26/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 98.2830
# Epoch 27/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 98.2323
# Epoch 28/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 98.1411
# Epoch 29/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 98.0875
# Epoch 30/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 98.0263
# Epoch 31/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 97.9499
# Epoch 32/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 97.9164
# Epoch 33/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 97.8316
# Epoch 34/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 97.7963
# Epoch 35/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 97.7240
# Epoch 36/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 97.6964
# Epoch 37/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 97.6328
# Epoch 38/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 97.5942
# Epoch 39/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 97.5464
# Epoch 40/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 97.4935
# Epoch 41/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 97.4308
# Epoch 42/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 97.4158
# Epoch 43/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 97.3695
# Epoch 44/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 97.3390
# Epoch 45/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 97.2997
# Epoch 46/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 97.2689
# Epoch 47/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 97.2093
# Epoch 48/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 97.1723
# Epoch 49/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 97.1416
# Epoch 50/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 97.1043
# Epoch 51/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 97.0807
# Epoch 52/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 97.0435
# Epoch 53/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 97.0119
# Epoch 54/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 97.0098
# Epoch 55/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.9596
# Epoch 56/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.9458
# Epoch 57/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.9088
# Epoch 58/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 96.8804
# Epoch 59/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 96.8641
# Epoch 60/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.8430
# Epoch 61/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.8195
# Epoch 62/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.7827
# Epoch 63/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.7346
# Epoch 64/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.7230
# Epoch 65/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.6926
# Epoch 66/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.6765
# Epoch 67/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.6465
# Epoch 68/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 96.6452
# Epoch 69/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.6131
# Epoch 70/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.5961
# Epoch 71/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.5613
# Epoch 72/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.5584
# Epoch 73/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 96.5530
# Epoch 74/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.5138
# Epoch 75/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.5249
# Epoch 76/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.4920
# Epoch 77/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.4591
# Epoch 78/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.4570
# Epoch 79/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 96.4580
# Epoch 80/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.4382
# Epoch 81/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.4065
# Epoch 82/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.3989
# Epoch 83/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.3910
# Epoch 84/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 96.3794
# Epoch 85/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 96.3675
# Epoch 86/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.3449
# Epoch 87/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 96.3408
# Epoch 88/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 96.3212
# Epoch 89/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.3122
# Epoch 90/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.2888
# Epoch 91/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.2931
# Epoch 92/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.2855
# Epoch 93/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.2829
# Epoch 94/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.2755
# Epoch 95/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.2418
# Epoch 96/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.2362
# Epoch 97/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.2171
# Epoch 98/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.2306
# Epoch 99/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.2191
# Epoch 100/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 96.1983
# 1875/1875 [==============================] - 2s 824us/step
# 225

# %%
# Define the number of images to generate
num_images_to_generate = 10

# Sample random points from the latent space (Gaussian distribution)
latent_points = np.random.normal(size=(num_images_to_generate, latent_dim))

# Generate images by decoding the sampled points
generated_images = decoder.predict(latent_points)
# Display the generated images
plt.figure(figsize=(10, 4))
for i in range(num_images_to_generate):
    plt.subplot(1, num_images_to_generate, i + 1)
    plt.imshow(generated_images[i].reshape((28, 28)), cmap='gray')  # Adjust the reshape dimensions
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 48ms/step
